# %% [markdown]
# <a href="https://colab.research.google.com/github/cenna-alias/test/blob/main/line_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

days = [1,2,3,4,5,6,7]
sales = [10,20,30,35,15,45,25]

plt.plot(days,sales,linestyle=':', marker='.', label='Sales',color='green')

plt.xlabel("Days")
plt.ylabel("Sale in each day")
plt.title("Basic line plot for sales analysis")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(1, 11)

y1 = x**2
y2 = 2*x

plt.plot(x, y1, label='square', linestyle=':', marker='o', color='red')
plt.plot(x, y2, label='double', linestyle='-', marker='s', color='blue')

plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.title("Line Plot of square and double")
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(1,21)
y = x*2
plt.scatter(x,y,s=2,color='orange')
plt.title("Scatter Plot")
plt.show()

# %%
x=np.arange(1,16)
y=np.arange(10001,10016)
plt.scatter(x,y,s=50,facecolors='red',edgecolors='blue')
plt.title("Scatter Plot")
plt.show()

# %%
categories = ['A','B','C']
values = (10,20,15)
plt.bar(categories,values,color='green',edgecolor='blue')
plt.title("Bar Chart")
plt.show()

# %%
categories = ['A','B','C']
values = (10,20,15)
plt.bar(categories,values)
plt.title("Bar Chart")
plt.show()

# %%
categories = ['A','B','C','D','E']
values = (10,20,15,20,35)
select = ['green','red','purple','pink','black']
plt.bar(categories,values,color=select,edgecolor='yellow',linewidth=5)
plt.title("Bar Chart")
plt.show()

# %%
weight = (50,70,85,90,45,65,76,87,44,60)
height = (150,176,185,190,145,165,176,187,144,160)
plt.scatter(weight,height,s=50,facecolors='yellow',edgecolors='green')
plt.xlabel("Weight")
plt.ylabel("Height")
plt.legend()
plt.title("Height and Weight analysis")
plt.show()
# Out:
# /tmp/ipykernel_3380/2714632102.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
product_list = ['Bag','Shoes','Salwar','Perfumes','Watch']
sales_amount = (999,1899,2900,599,1999)
select = ['orange','blue','black','red','purple']
plt.bar(product_list,sales_amount,color=select,edgecolor='yellow',linewidth=5,label='Sales')
plt.xlabel("Product_list")
plt.ylabel("Sales_amount")
plt.legend()
plt.title("Product Analysis")
plt.show()
